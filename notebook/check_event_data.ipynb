# %%
import numpy as np
import pandas as pd

import json

# %%
train = pd.read_csv('/code/data/raw/train.csv', nrows=10000)
specs = pd.read_csv('/code/data/raw/specs.csv')

# %%
train.head(20)
# Out:
#     event_id      game_session                 timestamp  \
# 0   27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1   27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2   77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3   b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4   1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# 5   1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.279Z
# 6   1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.913Z
# 7   1325467d  0848ef14a8dc6892  2019-09-06T17:55:07.546Z
# 8   1325467d  0848ef14a8dc6892  2019-09-06T17:55:07.979Z
# 9   1325467d  0848ef14a8dc6892  2019-09-06T17:55:08.566Z
# 10  1325467d  0848ef14a8dc6892  2019-09-06T17:55:08.966Z
# 11  1325467d  0848ef14a8dc6892  2019-09-06T17:55:09.673Z
# 12  1325467d  0848ef14a8dc6892  2019-09-06T17:55:09.930Z
# 13  1325467d  0848ef14a8dc6892  2019-09-06T17:55:10.157Z
# 14  1325467d  0848ef14a8dc6892  2019-09-06T17:55:10.414Z
# 15  1325467d  0848ef14a8dc6892  2019-09-06T17:55:10.648Z
# 16  1325467d  0848ef14a8dc6892  2019-09-06T17:55:10.911Z
# 17  1325467d  0848ef14a8dc6892  2019-09-06T17:55:11.178Z
# 18  b2dba42b  0848ef14a8dc6892  2019-09-06T17:55:11.246Z
# 19  1325467d  0848ef14a8dc6892  2019-09-06T17:55:11.592Z
#
#                                            event_data installation_id  \
# 0              {"event_code": 2000, "event_count": 1}        0001e90f
# 1              {"event_code": 2000, "event_count": 1}        0001e90f
# 2   {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3   {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4   {"description":"Let's build a sandcastle! Firs...        0001e90f
# 5   {"coordinates":{"x":583,"y":605,"stage_width":...        0001e90f
# 6   {"coordinates":{"x":601,"y":570,"stage_width":...        0001e90f
# 7   {"coordinates":{"x":250,"y":665,"stage_width":...        0001e90f
# 8   {"coordinates":{"x":279,"y":629,"stage_width":...        0001e90f
# 9   {"coordinates":{"x":839,"y":654,"stage_width":...        0001e90f
# 10  {"coordinates":{"x":807,"y":619,"stage_width":...        0001e90f
# 11  {"coordinates":{"x":810,"y":611,"stage_width":...        0001e90f
# 12  {"coordinates":{"x":827,"y":584,"stage_width":...        0001e90f
# 13  {"coordinates":{"x":823,"y":615,"stage_width":...        0001e90f
# 14  {"coordinates":{"x":832,"y":614,"stage_width":...        0001e90f
# 15  {"coordinates":{"x":875,"y":631,"stage_width":...        0001e90f
# 16  {"coordinates":{"x":871,"y":637,"stage_width":...        0001e90f
# 17  {"coordinates":{"x":890,"y":645,"stage_width":...        0001e90f
# 18  {"description":"Drag the shovel to the molds t...        0001e90f
# 19  {"coordinates":{"x":866,"y":650,"stage_width":...        0001e90f
#
#     event_count  event_code  game_time                          title  \
# 0             1        2000          0        Welcome to Lost Lagoon!
# 1             1        2000          0           Magma Peak - Level 1
# 2             1        2000          0  Sandcastle Builder (Activity)
# 3             2        3010         53  Sandcastle Builder (Activity)
# 4             3        3110       6972  Sandcastle Builder (Activity)
# 5             4        4070       9991  Sandcastle Builder (Activity)
# 6             5        4070      10622  Sandcastle Builder (Activity)
# 7             6        4070      11255  Sandcastle Builder (Activity)
# 8             7        4070      11689  Sandcastle Builder (Activity)
# 9             8        4070      12272  Sandcastle Builder (Activity)
# 10            9        4070      12672  Sandcastle Builder (Activity)
# 11           10        4070      13389  Sandcastle Builder (Activity)
# 12           11        4070      13639  Sandcastle Builder (Activity)
# 13           12        4070      13872  Sandcastle Builder (Activity)
# 14           13        4070      14122  Sandcastle Builder (Activity)
# 15           14        4070      14356  Sandcastle Builder (Activity)
# 16           15        4070      14622  Sandcastle Builder (Activity)
# 17           16        4070      14889  Sandcastle Builder (Activity)
# 18           17        3010      14956  Sandcastle Builder (Activity)
# 19           18        4070      15306  Sandcastle Builder (Activity)
#
#         type      world
# 0       Clip       NONE
# 1       Clip  MAGMAPEAK
# 2   Activity  MAGMAPEAK
# 3   Activity  MAGMAPEAK
# 4   Activity  MAGMAPEAK
# 5   Activity  MAGMAPEAK
# 6   Activity  MAGMAPEAK
# 7   Activity  MAGMAPEAK
# 8   Activity  MAGMAPEAK
# 9   Activity  MAGMAPEAK
# 10  Activity  MAGMAPEAK
# 11  Activity  MAGMAPEAK
# 12  Activity  MAGMAPEAK
# 13  Activity  MAGMAPEAK
# 14  Activity  MAGMAPEAK
# 15  Activity  MAGMAPEAK
# 16  Activity  MAGMAPEAK
# 17  Activity  MAGMAPEAK
# 18  Activity  MAGMAPEAK
# 19  Activity  MAGMAPEAK

# %%
train[train.type=='Activity']
# Out:
#       event_id      game_session                 timestamp  \
# 2     77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3     b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4     1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# 5     1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.279Z
# 6     1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.913Z
# ...        ...               ...                       ...
# 9995  5e812b27  0f0820e60515b9d2  2019-10-10T19:02:03.750Z
# 9996  9ee1c98c  0f0820e60515b9d2  2019-10-10T19:02:04.651Z
# 9997  b2dba42b  0f0820e60515b9d2  2019-10-10T19:02:04.651Z
# 9998  1bb5fbdb  0f0820e60515b9d2  2019-10-10T19:02:05.345Z
# 9999  5e812b27  0f0820e60515b9d2  2019-10-10T19:02:05.882Z
#
#                                              event_data installation_id  \
# 2     {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3     {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4     {"description":"Let's build a sandcastle! Firs...        0001e90f
# 5     {"coordinates":{"x":583,"y":605,"stage_width":...        0001e90f
# 6     {"coordinates":{"x":601,"y":570,"stage_width":...        0001e90f
# ...                                                 ...             ...
# 9995  {"size":0,"coordinates":{"x":782,"y":207,"stag...        00195df7
# 9996  {"size":2,"sand":1,"duration":518,"coordinates...        00195df7
# 9997  {"description":"Fill it up!","identifier":"Dot...        00195df7
# 9998  {"description":"Fill it up!","identifier":"Dot...        00195df7
# 9999  {"size":0,"coordinates":{"x":782,"y":207,"stag...        00195df7
#
#       event_count  event_code  game_time                          title  \
# 2               1        2000          0  Sandcastle Builder (Activity)
# 3               2        3010         53  Sandcastle Builder (Activity)
# 4               3        3110       6972  Sandcastle Builder (Activity)
# 5               4        4070       9991  Sandcastle Builder (Activity)
# 6               5        4070      10622  Sandcastle Builder (Activity)
# ...           ...         ...        ...                            ...
# 9995          179        4030     172434  Sandcastle Builder (Activity)
# 9996          181        4021     173351  Sandcastle Builder (Activity)
# 9997          180        3010     173351  Sandcastle Builder (Activity)
# 9998          182        3110     174051  Sandcastle Builder (Activity)
# 9999          183        4030     174567  Sandcastle Builder (Activity)
#
#           type      world
# 2     Activity  MAGMAPEAK
# 3     Activity  MAGMAPEAK
# 4     Activity  MAGMAPEAK
# 5     Activity  MAGMAPEAK
# 6     Activity  MAGMAPEAK
# ...        ...        ...
# 9995  Activity  MAGMAPEAK
# 9996  Activity  MAGMAPEAK
# 9997  Activity  MAGMAPEAK
# 9998  Activity  MAGMAPEAK
# 9999  Activity  MAGMAPEAK
#
# [5332 rows x 11 columns]

# %%
train[train.game_session=='0848ef14a8dc6892']
# Out:
#      event_id      game_session                 timestamp  \
# 2    77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3    b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4    1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# 5    1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.279Z
# 6    1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.913Z
# ..        ...               ...                       ...
# 264  84538528  0848ef14a8dc6892  2019-09-06T17:58:05.792Z
# 265  b2dba42b  0848ef14a8dc6892  2019-09-06T17:58:05.793Z
# 266  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:58:07.009Z
# 267  5e812b27  0848ef14a8dc6892  2019-09-06T17:58:07.423Z
# 268  c58186bf  0848ef14a8dc6892  2019-09-06T17:58:10.609Z
#
#                                             event_data installation_id  \
# 2    {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3    {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4    {"description":"Let's build a sandcastle! Firs...        0001e90f
# 5    {"coordinates":{"x":583,"y":605,"stage_width":...        0001e90f
# 6    {"coordinates":{"x":601,"y":570,"stage_width":...        0001e90f
# ..                                                 ...             ...
# 264  {"size":3,"castles_placed":[{"size":2,"positio...        0001e90f
# 265  {"description":"So cool!","identifier":"Dot_So...        0001e90f
# 266  {"description":"So cool!","identifier":"Dot_So...        0001e90f
# 267  {"size":0,"coordinates":{"x":782,"y":207,"stag...        0001e90f
# 268  {"size":0,"coordinates":{"x":272,"y":733,"stag...        0001e90f
#
#      event_count  event_code  game_time                          title  \
# 2              1        2000          0  Sandcastle Builder (Activity)
# 3              2        3010         53  Sandcastle Builder (Activity)
# 4              3        3110       6972  Sandcastle Builder (Activity)
# 5              4        4070       9991  Sandcastle Builder (Activity)
# 6              5        4070      10622  Sandcastle Builder (Activity)
# ..           ...         ...        ...                            ...
# 264          263        4020     189518  Sandcastle Builder (Activity)
# 265          264        3010     189518  Sandcastle Builder (Activity)
# 266          265        3110     190735  Sandcastle Builder (Activity)
# 267          266        4030     191135  Sandcastle Builder (Activity)
# 268          267        4035     194335  Sandcastle Builder (Activity)
#
#          type      world
# 2    Activity  MAGMAPEAK
# 3    Activity  MAGMAPEAK
# 4    Activity  MAGMAPEAK
# 5    Activity  MAGMAPEAK
# 6    Activity  MAGMAPEAK
# ..        ...        ...
# 264  Activity  MAGMAPEAK
# 265  Activity  MAGMAPEAK
# 266  Activity  MAGMAPEAK
# 267  Activity  MAGMAPEAK
# 268  Activity  MAGMAPEAK
#
# [267 rows x 11 columns]

# %%
train[train.game_session=='0848ef14a8dc6892'].event_data
# Out:
# 2      {"version":"1.0","event_count":1,"game_time":0...
# 3      {"description":"Let's build a sandcastle! Firs...
# 4      {"description":"Let's build a sandcastle! Firs...
# 5      {"coordinates":{"x":583,"y":605,"stage_width":...
# 6      {"coordinates":{"x":601,"y":570,"stage_width":...
#                              ...
# 264    {"size":3,"castles_placed":[{"size":2,"positio...
# 265    {"description":"So cool!","identifier":"Dot_So...
# 266    {"description":"So cool!","identifier":"Dot_So...
# 267    {"size":0,"coordinates":{"x":782,"y":207,"stag...
# 268    {"size":0,"coordinates":{"x":272,"y":733,"stag...
# Name: event_data, Length: 267, dtype: object

# %%
event_data = pd.io.json.json_normalize(train.event_data.apply(json.loads))
event_data.head(20)
# Out:
#     event_code  event_count version  game_time  \
# 0         2000            1     NaN        NaN
# 1         2000            1     NaN        NaN
# 2         2000            1     1.0        0.0
# 3         3010            2     NaN       53.0
# 4         3110            3     NaN     6972.0
# 5         4070            4     NaN     9991.0
# 6         4070            5     NaN    10622.0
# 7         4070            6     NaN    11255.0
# 8         4070            7     NaN    11689.0
# 9         4070            8     NaN    12272.0
# 10        4070            9     NaN    12672.0
# 11        4070           10     NaN    13389.0
# 12        4070           11     NaN    13639.0
# 13        4070           12     NaN    13872.0
# 14        4070           13     NaN    14122.0
# 15        4070           14     NaN    14356.0
# 16        4070           15     NaN    14622.0
# 17        4070           16     NaN    14889.0
# 18        3010           17     NaN    14956.0
# 19        4070           18     NaN    15306.0
#
#                                           description  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Let's build a sandcastle! First, fill up your ...
# 4   Let's build a sandcastle! First, fill up your ...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18      Drag the shovel to the molds to fill them up!
# 19                                                NaN
#
#                                        identifier media_type  total_duration  \
# 0                                             NaN        NaN             NaN
# 1                                             NaN        NaN             NaN
# 2                                             NaN        NaN             NaN
# 3   Dot_LetsSandcastle,Dot_FillMold,Dot_MoldShape      audio          6758.0
# 4   Dot_LetsSandcastle,Dot_FillMold,Dot_MoldShape      audio             NaN
# 5                                             NaN        NaN             NaN
# 6                                             NaN        NaN             NaN
# 7                                             NaN        NaN             NaN
# 8                                             NaN        NaN             NaN
# 9                                             NaN        NaN             NaN
# 10                                            NaN        NaN             NaN
# 11                                            NaN        NaN             NaN
# 12                                            NaN        NaN             NaN
# 13                                            NaN        NaN             NaN
# 14                                            NaN        NaN             NaN
# 15                                            NaN        NaN             NaN
# 16                                            NaN        NaN             NaN
# 17                                            NaN        NaN             NaN
# 18                                 Dot_DragShovel      audio          2070.0
# 19                                            NaN        NaN             NaN
#
#     duration  coordinates.x  ...  side  table_weights  starting_weights  \
# 0        NaN            NaN  ...   NaN            NaN               NaN
# 1        NaN            NaN  ...   NaN            NaN               NaN
# 2        NaN            NaN  ...   NaN            NaN               NaN
# 3        NaN            NaN  ...   NaN            NaN               NaN
# 4     6919.0            NaN  ...   NaN            NaN               NaN
# 5        NaN          583.0  ...   NaN            NaN               NaN
# 6        NaN          601.0  ...   NaN            NaN               NaN
# 7        NaN          250.0  ...   NaN            NaN               NaN
# 8        NaN          279.0  ...   NaN            NaN               NaN
# 9        NaN          839.0  ...   NaN            NaN               NaN
# 10       NaN          807.0  ...   NaN            NaN               NaN
# 11       NaN          810.0  ...   NaN            NaN               NaN
# 12       NaN          827.0  ...   NaN            NaN               NaN
# 13       NaN          823.0  ...   NaN            NaN               NaN
# 14       NaN          832.0  ...   NaN            NaN               NaN
# 15       NaN          875.0  ...   NaN            NaN               NaN
# 16       NaN          871.0  ...   NaN            NaN               NaN
# 17       NaN          890.0  ...   NaN            NaN               NaN
# 18       NaN            NaN  ...   NaN            NaN               NaN
# 19       NaN          866.0  ...   NaN            NaN               NaN
#
#    tape_length bug_length  dwell_time  total_bowls bowls  has_toy  bowl_id
# 0          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 1          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 2          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 3          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 4          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 5          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 6          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 7          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 8          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 9          NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 10         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 11         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 12         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 13         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 14         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 15         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 16         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 17         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 18         NaN        NaN         NaN          NaN   NaN      NaN      NaN
# 19         NaN        NaN         NaN          NaN   NaN      NaN      NaN
#
# [20 rows x 117 columns]

# %%
x = event_data['coordinates.x']/event_data['coordinates.stage_width']

# %%
np.std(x)
# Out:
# 0.258952960229443

# %%
set(event_data['description'])
# Out:
# {'1',
#  '2',
#  '3',
#  '4',
#  '5',
#  'A cow that humongous is gonna need a tub bigger than that.',
#  'A hog that big and that filthy is going to need a soap bigger than that.',
#  'Ah! See the pans move? Now put a bowl on the other pan.',
#  "Almost! But they aren't quite in the right houses yet.",
#  "Almost! But you didn't fly far enough. Try again!",
#  "Almost! But you didn't land between the cliff and the other dinosaur.",
#  'Almost! Try again!',
#  'Alright! This one is the littlest mushroom, and this one is the biggest!',
#  'Amazing!',
#  "And done! That mold is so small, it doesn't need a lot of sand.",
#  "And it's full! I'll put this one over here, so you can make another one!",
#  'Can you match the animals to the pails of water that are just the right size?',
#  'Dot_StillPartyHats',
#  'Drag a bottle of sand over to the big bottle!',
#  'Drag a bug over here! idle',
#  'Drag the mushrooms to the tree stumps!',
#  'Drag the shovel to the molds to fill them up!',
#  'Drag them to the correct house from shortest to tallest!',
#  'Drag them to the correct house from tallest to shortest!',
#  'Drag your mold to the sand to place it!',
#  "Each circle of the caterpillar's body is a unit. Now we know how many units tall each bird is.",
#  'Eight. Alright! The tub is full! You estimated just right!',
#  "Epidermis' toy is in one of these bowls of camel food! But which one? We shall find the toys in no time thanks to my pan balance! This amazing device for measuring weight. First, move a bowl to one of the pans.",
#  'Everybody has just the right amount of soap! Yes!',
#  'Everybody has just the right amount of water. Alright!',
#  "Everybody's got a tub that's just the right size. All right!",
#  'Fill it up!',
#  'First you need to match the animals to the tubs that are just the right size!',
#  'First, click the space where you want your dinosaur to start.',
#  'Five!',
#  'Four!',
#  'Four.',
#  'Four. Alright! The tub is full! You estimated just right!',
#  'Go lower!',
#  'Good job, team!',
#  'Good job, that was just right!',
#  'Good measuring!',
#  'Great flying! Time for the last round.',
#  'Great job! Now the dinosaurs will have lots of energy!',
#  "Great job! That's the right order!",
#  'Great job! Those thirsty dinosaurs got plenty of water. On with the games!',
#  'Great job! You did it!',
#  'Great job! You did it.',
#  "Hello! Today, we're making sand art! All we've got to do is take the sand from these bottles, and pour them into this big bottle! You can use any colors, and make whatever pattern you want! Cool, right? Drag a bottle of sand over to the big bottle!",
#  "Here's the target mark.   Tap two dinosaurs whose total size will raise the water to level  four.",
#  "Here's the target mark.   Tap two dinosaurs whose total size will raise the water to level  nine.",
#  "Here's the target mark.   Tap two dinosaurs whose total size will raise the water to level  seven.",
#  "Here's the target mark.   Tap two dinosaurs whose total size will raise the water to level  six.",
#  "Here's the target mark.  Tap one dinosaur whose size will raise the water to level  one.",
#  "Here's the target mark.  Tap one dinosaur whose size will raise the water to level  six.",
#  "Here's the target mark.  Tap one dinosaur whose size will raise the water to level  three.",
#  "Hey look! It's The Pig! I wonder what would happen if you put The Pig on the see-saw... idle",
#  "Hmm, you're getting close but the dinosaurs aren't all in the right houses yet. Try again!",
#  "Hmm. Those don't seem to be in order from shortest to tallest.",
#  "Hmmm, the egg was too small and there's not enough water.",
#  'How many blocks long is this rock?',
#  "How many containers will it take to fill the tub altogether? Let's estimate. That means, make a careful guess.",
#  'How many crayons long is this rock?',
#  'How many dice long is this rock?',
#  'How many paperclips long is this rock?',
#  'How many shovels long is this rock?',
#  'How many toothbrushes long is this rock?',
#  "How many units tall is each bird? Let's count! Drag the correct party hat to each bird.",
#  "How many units tall is each bird? Let's count! One two three four! Uh oh. That number is too big. One two three four five six seven eight! Hm. That number is too small. One two three four five! Uh oh. That number is too big. Dot_TrySwitchingHats",
#  'I am in awe of your skills!',
#  'I bet you could get her cleaned up with a smaller soap.',
#  'I want you to fly farther than the other dinosaur did.',
#  'I want you to land as close as possible to the other dinosaur.',
#  'I want you to land closer to the tree than the other dinosaur did.',
#  'I want you to land in between the cliff and the other dinosaur.',
#  "I'd try something bigger.",
#  "I'll add this one to your collection!",
#  'If you want to pick a flower, drag it to my basket!',
#  'If you want to try another color, just put that bottle back and try a new bottle!',
#  "It's Chow Time! We have some VERY hungry dinosaurs waiting. Let's feed them! Big dinosaurs eat a lot of food, small dinosaurs only eat a little!",
#  "It's the super powerful, Queen Cleopatra! What's the problem, Cle? My silly camel Epidermis has lost his toys in his food. Can you help us find them?",
#  "Let's build a sandcastle! First, fill up your mold with sand! You can use the shovel here. The mold gives the sand its shape!",
#  "Let's measure some big rocks with something smaller. You can move the object under the rock to figure out how long the rock is Once you know how many objects you need, tap on the right number.",
#  "Let's put this bug back where it came from.",
#  "Let's set off these fireworks. We can drag them to any height we want!",
#  "Let's take a practice run! First, tap the space where you want your dinosaur to start.",
#  "Let's warm up. Tap a dinosaur to take a practice dive.",
#  'Lets try something new.',
#  'Look at all those itty, bitty chickies! You can drag the chickies to the see saw! Put them on either side.',
#  'Look at it go! idle',
#  'Look at you, you lean, mean, plant-growing machine!',
#  'Look! Each bucket is exactly the right size for the statue! They each hold the same amount of liquid!',
#  "Looks like there's no water left... let's make some more rain! Fill in the clouds to make it rain. That will fill up the pond with water!",
#  'Looks like we have too many containers! Alright! The tub is full!',
#  'Move the toy around! Or squeeze it to hear a silly sound.',
#  'Next time, try to use a smaller egg to fill a small hole with water.',
#  'Next, move the eggshell to a watering hole, and tap to pour the water in the hole.',
#  'Nice job!',
#  'Nice work. All the caterpillars match the height of the birds.',
#  "Now match the animals to the soap that's just the right size!",
#  'Now order these mushrooms by height! Shortest over here, to tallest over here.',
#  'Now there are five holes and five dinosaurs. Match the size of the egg to the size of the hole.',
#  'Now there are three holes and three dinosaurs.',
#  'Now use this ruler to see how long this bug is!',
#  "Now we have four bowls! Epidermis' toy is in one of these bowls of camel food! But which one?",
#  "Now we have three bowls. Epidermis' toy is in one of these bowls of camel food! But which one? Let's weigh two of the bowls first!",
#  'Now, tap the green "go" button!',
#  'Oh, wow!',
#  "Okay, team, it's getting harder now.",
#  'Okay, team, we have to win four dives.',
#  'Okay, when you want to check your answer - tap here!',
#  'One!',
#  'One.',
#  'Ooo, stripes!',
#  'Oops!  The water level is too low.  Try choosing a larger dinosaur.',
#  'Oops!  The water level is too low. Try choosing two larger dinosaurs.',
#  'Oops! That was too much water!',
#  "Our competitors are getting thirsty, folks. Let's get everyone hydrated at the Hydration Station!",
#  "Peggy Peg is splashing in the bathroom and she needs your help! We're going to have a bubble party and we need your help filling the tub with water!",
#  'Problem solved, Cleo! You found all of his toys! Epidermis loves playing pan-balance with you. Would you like to play again?',
#  'Pull three mushrooms out of the ground and order them from shortest to tallest!',
#  'Put the right sized bucket under each statue. Match the bucket to the same sized statue!',
#  'Seven!',
#  'Since that was a large dinosaur,  the water level went up a lot.',
#  'Since that was a medium dinosaur, the water level went up a medium amount.',
#  'Since that was a small dinosaur, the water level went up just a little.',
#  'Six!',
#  'So close! But you flew too far. Try again!',
#  'So cool!',
#  "So the farmer wants to take a picture of his animals. But look at them, they're totally filthy! Could you help the farmer wash them up 'til they're all sparkly and clean?",
#  'Tap a bug! See what happens.',
#  'Tap another dinosaur.',
#  "Tap on each container to pour it in. Let's add this one, and then go down the line.",
#  'Tap on the container to pour water in the tub.',
#  'Tap the cloud to start the rain shower!',
#  'That bowl is too light!',
#  'That egg held the right amount of water to fill that hole.',
#  "That little chicken doesn't need such a big bar of soap.",
#  'That looks so cool!',
#  'That one was so low!',
#  'That tub is just too small for the hog.',
#  'That tub is too big for that itty-bitty chicky!',
#  'That tub is too big for the pig.',
#  'That tub is too small for the pig.',
#  "That's a big cloud!",
#  "That's a pretty big hog there. You're going to need more water than that.",
#  "That's a pretty big pig there. You're going to need more water than that.",
#  "That's a small cloud, so it only made a little rain.",
#  "That's it!",
#  "That's it!  The further back you start, the further your dinosaur will fly!",
#  "That's it!  The further back you start, the further your dinosaur will fly! Take one more practice flight and try to fly as far as you can.",
#  "That's it! Thanks!",
#  "That's not enough food. Try putting a piece on the scale, to make that side heavier!",
#  "That's one!",
#  "That's right!",
#  "That's too much food. Try taking a piece off the scale, to make that side lighter!",
#  'The Claw Stars going for the gold in Dinosaur Dive!',
#  'The bigger the egg, the more water it can hold! Match the size of the egg to the size of the hole. Small hole, small egg. Big hole, big egg. Ready? Give that thirsty dinosaur some water! [Laughter]',
#  "The hog isn't so big. You could give him a smaller soap.",
#  "The hog isn't that big. A little less water should be enough.",
#  'The more chickies, the heavier that side will get.',
#  "The other team will fly first. To win the gold, follow my instructions. I'll tell you where to land.",
#  "The sheep doesn't need such a big tub.",
#  "The sheep isn't all that big, so she doesn't need so much water.",
#  'The small dinosaurs will move the smallest amount of water. The medium dinosaurs, a medium amount of water, and the large dinosaurs, a large amount of water.',
#  'The warm-up is over, folks. Let the game begin!',
#  'There are two holes and two dinosaurs. Match the size of the egg to the size of the hole.',
#  'There goes the other team.',
#  "There we have it, folks. Some magnificent dives by the  Claw Stars.   They've won the gold!!",
#  'These dinosaurs are awfully thirsty. Fill in the clouds to make it rain. That will fill up the pond with water!',
#  'These dinosaurs want your help getting sorted into the right houses.',
#  'These lines show the correct heights of the mushrooms. Try again!',
#  'This bug is so tiny!',
#  'This bug is super long!',
#  'This garden is plant-astic!',
#  'This is a pan balance. You use it to tell how heavy something is. Put rocks on one side, and copper weights on the other side, and once the two sides are the same, press the green check button!',
#  'This is how much water one container holds.',
#  "This mold is really big so it's going to need a lot of sand to fill it!",
#  'Three!',
#  'Three.',
#  "To get her clean, I'd use more water!",
#  "To make the sure dinosaur eats the right amount tap and drag the food to the scale, until it's balanced!",
#  "To make the sure dinosaur eats the right amount tap and drag the food to the scale, until it's balanced! The scale is balanced when the two arrows are lined up, and green You can add, or take away, food if the scale is not balanced.",
#  'To pick a mushroom, pull it out of the ground with your finger!',
#  'To play again, tap here!',
#  'Try making a long wall.',
#  'Try making a tall tower.',
#  'Try tapping stuff to make funny things happen!',
#  'Two!',
#  'Two.',
#  'Uh oh. This caterpillar is too tall for that bird.',
#  'Uh-oh!  The water level is too high. Try choosing two smaller dinosaurs.',
#  "Uh-oh! That's not the right length. Try again!",
#  'Use the caterpillars to measure the birds. Pull the caterpillars out of their holes with your finger.',
#  "Volume is the amount of space something takes up.  Let's look at our diving team.",
#  'Wanna help the farmer clean up the animals again?',
#  'Watch me first, kids. First, tap an eggshell. Then, hold it under the water to fill it.',
#  'Watch the see-saw go up and down! idle',
#  'Welcome to the garden! Which could really use some flowers... Oh oh, a watering can! Pick it up!',
#  'When one side tips down… that bowl is heavier. Now think… which bowl has the toy inside?',
#  "When the pan balance is balanced, the arm goes straight across. That means these bowls are the same weight. But, we're looking for the heavier bowl.",
#  "When you want to check to see if you're right, tap here.",
#  "When you're all done, tap this button.",
#  'Which bar of soap is right for the pig?',
#  'Which container would you like to use? Pick one!',
#  "Which one of these bowls has Epidermis' toy?",
#  'Which pail is just right for the sheep?',
#  'Which pail is right for the chicken?',
#  'Which pail is right for the cow?',
#  'Which pail is right for the pig?',
#  'Which pail of water is right for the hog?',
#  'Which soap is just right for the chicken?',
#  'Which soap is right for the hog?',
#  'Which soap is right for the sheep?',
#  'Which soap is the right size for the cow?',
#  'Which tub is just right for the chicken?',
#  'Which tub is right for the cow?',
#  'Which tub is right for the hog?',
#  'Which tub is the right size for the sheep?',
#  'Which tub would fit the pig?',
#  'Whoa so cool!',
#  'Whoa that one was so high!',
#  'Whoa-oh! That is one tall flower!',
#  'Whoops. This caterpillar is too short for that bird.',
#  'Woo hoo! You did it! You helped the farmer scrub-a-dub-dub the animals so they are all clean and cute and cuddly just in time to have their picture taken. Smile!',
#  'Wow!',
#  'Wow! Pig sure is heavy. Those chickies are so light! idle',
#  'Wow! That looks so cool!',
#  'You can drag the chickies to the see saw! Put them on either side.',
#  'You did it!',
#  "You did it! That's the right order.",
#  'You found a bathtoy!',
#  'You have a green thumb - which is a good thing!',
#  'You have amazing powers!',
#  'You moved your dinosaur Eight spaces.',
#  'You moved your dinosaur Eight spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Five spaces.',
#  'You moved your dinosaur Four spaces.',
#  'You moved your dinosaur Four spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Nine spaces.',
#  'You moved your dinosaur Nine spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Seven spaces.',
#  'You moved your dinosaur Seven spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Six spaces.',
#  'You moved your dinosaur Six spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Ten spaces.',
#  'You moved your dinosaur Ten spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Three spaces.',
#  'You moved your dinosaur Three spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  'You moved your dinosaur Two spaces.',
#  'You moved your dinosaur Two spaces. If you change your mind,  you can tap a different space to move your dinosaur.',
#  "You've made Epidermis so happy!",
#  'and three!',
#  nan,
#  'piglovestriangles',
#  'two...',
#  "walk_in Check it out! This is my bug tank! Pretty neat isn't it? I never realized there were so many bugs in so many different sizes! Tap a bug! See what happens."}

# %%
train[train.type=='Assessment']
# Out:
#       event_id      game_session                 timestamp  \
# 2185  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 2186  db02c830  901acc108f55a5a1  2019-08-06T05:22:01.400Z
# 2187  a1e4395d  901acc108f55a5a1  2019-08-06T05:22:01.403Z
# 2188  a52b92d5  901acc108f55a5a1  2019-08-06T05:22:05.242Z
# 2189  a1e4395d  901acc108f55a5a1  2019-08-06T05:22:05.244Z
# ...        ...               ...                       ...
# 8076  51102b85  ae691ec5ad5652cf  2019-09-22T16:33:06.862Z
# 8077  8fee50e2  ae691ec5ad5652cf  2019-09-22T16:33:07.460Z
# 8078  070a5291  ae691ec5ad5652cf  2019-09-22T16:33:08.061Z
# 8079  f6947f54  ae691ec5ad5652cf  2019-09-22T16:33:08.063Z
# 8080  3393b68b  ae691ec5ad5652cf  2019-09-22T16:33:10.216Z
#
#                                              event_data installation_id  \
# 2185  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# 2186  {"event_count":2,"game_time":37,"event_code":2...        0006a69f
# 2187  {"description":"Pull three mushrooms out of th...        0006a69f
# 2188  {"description":"Pull three mushrooms out of th...        0006a69f
# 2189  {"description":"To pick a mushroom, pull it ou...        0006a69f
# ...                                                 ...             ...
# 8076  {"hat":5,"caterpillar":"","coordinates":{"x":2...        00129856
# 8077  {"hat":5,"destination":"right","coordinates":{...        00129856
# 8078  {"correct":true,"hats":[4,8,5],"event_count":3...        00129856
# 8079  {"duration":21517,"misses":0,"stage_number":2,...        00129856
# 8080  {"session_duration":39701,"event_count":40,"ga...        00129856
#
#       event_count  event_code  game_time                         title  \
# 2185            1        2000          0  Mushroom Sorter (Assessment)
# 2186            2        2025         37  Mushroom Sorter (Assessment)
# 2187            3        3010         37  Mushroom Sorter (Assessment)
# 2188            4        3110       3901  Mushroom Sorter (Assessment)
# 2189            5        3010       3901  Mushroom Sorter (Assessment)
# ...           ...         ...        ...                           ...
# 8076           36        4030      36334    Bird Measurer (Assessment)
# 8077           37        4020      36951    Bird Measurer (Assessment)
# 8078           38        4100      37535    Bird Measurer (Assessment)
# 8079           39        2030      37535    Bird Measurer (Assessment)
# 8080           40        2010      39701    Bird Measurer (Assessment)
#
#             type        world
# 2185  Assessment  TREETOPCITY
# 2186  Assessment  TREETOPCITY
# 2187  Assessment  TREETOPCITY
# 2188  Assessment  TREETOPCITY
# 2189  Assessment  TREETOPCITY
# ...          ...          ...
# 8076  Assessment  TREETOPCITY
# 8077  Assessment  TREETOPCITY
# 8078  Assessment  TREETOPCITY
# 8079  Assessment  TREETOPCITY
# 8080  Assessment  TREETOPCITY
#
# [647 rows x 11 columns]

# %%
a = json.loads(train.iloc[12].event_data)
print(a)
# Out:
# {'coordinates': {'x': 827, 'y': 584, 'stage_width': 1015, 'stage_height': 762}, 'event_count': 11, 'game_time': 13639, 'event_code': 4070}

# %%
train[train.type=='Game']
# Out:
#       event_id      game_session                 timestamp  \
# 362   6d90d394  f11eb823348bfa23  2019-09-06T18:00:51.915Z
# 363   7040c096  f11eb823348bfa23  2019-09-06T18:00:56.121Z
# 364   5a848010  f11eb823348bfa23  2019-09-06T18:00:57.986Z
# 365   4a09ace1  f11eb823348bfa23  2019-09-06T18:01:11.792Z
# 366   dcaede90  f11eb823348bfa23  2019-09-06T18:01:13.792Z
# ...        ...               ...                       ...
# 9810  37db1c2f  fb13c8a7665bd25c  2019-09-04T15:33:32.486Z
# 9811  3bf1cf26  fb13c8a7665bd25c  2019-09-04T15:33:32.710Z
# 9812  1af8be29  fb13c8a7665bd25c  2019-09-04T15:33:32.711Z
# 9813  3d8c61b0  fb13c8a7665bd25c  2019-09-04T15:33:32.736Z
# 9814  8af75982  fb13c8a7665bd25c  2019-09-04T15:33:33.542Z
#
#                                              event_data installation_id  \
# 362   {"version":"1.0","level":0,"round":0,"event_co...        0001e90f
# 363   {"coordinates":{"x":1278,"y":957,"stage_width"...        0001e90f
# 364   {"movie_id":"scrubadub_intro","duration":13766...        0001e90f
# 365   {"movie_id":"scrubadub_intro","duration":13766...        0001e90f
# 366   {"level":1,"round":0,"event_count":5,"game_tim...        0001e90f
# ...                                                 ...             ...
# 9810  {"has_toy":false,"bowl_id":2,"scale_contents":...        0016b7cc
# 9811  {"description":"That bowl is too light!","iden...        0016b7cc
# 9812  {"description":"That bowl is too light!","iden...        0016b7cc
# 9813  {"source":"resources","has_toy":true,"bowl_id"...        0016b7cc
# 9814  {"source":"resources","bowl_id":1,"position":1...        0016b7cc
#
#       event_count  event_code  game_time        title  type         world
# 362             1        2000          0  Scrub-A-Dub  Game     MAGMAPEAK
# 363             2        4010       4205  Scrub-A-Dub  Game     MAGMAPEAK
# 364             3        2080       6057  Scrub-A-Dub  Game     MAGMAPEAK
# 365             4        2083      19873  Scrub-A-Dub  Game     MAGMAPEAK
# 366             5        2040      21873  Scrub-A-Dub  Game     MAGMAPEAK
# ...           ...         ...        ...          ...   ...           ...
# 9810          196        4045     155659  Happy Camel  Game  CRYSTALCAVES
# 9811          197        3120     155876  Happy Camel  Game  CRYSTALCAVES
# 9812          198        3020     155876  Happy Camel  Game  CRYSTALCAVES
# 9813          199        4030     155892  Happy Camel  Game  CRYSTALCAVES
# 9814          200        4020     156709  Happy Camel  Game  CRYSTALCAVES
#
# [3906 rows x 11 columns]

# %%
specs[specs.args.str.contains('coordinates')]
# Out:
#      event_id                                               info  \
# 6    bc8f2793  This event occurs when the player drops a weig...
# 8    cdd22e43  This event occurs when the player drags a chic...
# 11   4b5efe37  This event occurs when the player clicks to st...
# 13   3d63345e  This event occurs when the player drags a crys...
# 31   8fee50e2  This event occurs when the player places a hat...
# ..        ...                                                ...
# 359  2fb91ec1  This event occurs when the player clicks to ha...
# 362  28ed704e  This event occurs when the player picks one of...
# 372  5be391b5  This event occurs when the player clicks to st...
# 375  5e3ea25a  This event occurs when the player clicks on so...
# 380  7040c096  This event occurs when the player clicks to st...
#
#                                                   args
# 6    [{"name":"game_time","type":"int","info":"mill...
# 8    [{"name":"game_time","type":"int","info":"mill...
# 11   [{"name":"game_time","type":"int","info":"mill...
# 13   [{"name":"game_time","type":"int","info":"mill...
# 31   [{"name":"game_time","type":"int","info":"mill...
# ..                                                 ...
# 359  [{"name":"game_time","type":"int","info":"mill...
# 362  [{"name":"game_time","type":"int","info":"mill...
# 372  [{"name":"game_time","type":"int","info":"mill...
# 375  [{"name":"game_time","type":"int","info":"mill...
# 380  [{"name":"game_time","type":"int","info":"mill...
#
# [103 rows x 3 columns]

# %%
for i in specs[specs.args.str.contains('coordinates')][specs.event_id=='7040c096'].args:
    print(i)
# Out:
# [{"name":"game_time","type":"int","info":"millisecond count since start of game"},{"name":"round","type":"int","info":"number of the current round when the event takes place or 0 if no round"},{"name":"level","type":"int","info":"number of the current level when the event takes place or 0 if no level"},{"name":"coordinates","type":"object","info":"the game screen coordinates of the click\r\ndictionary:\r\n{“x”: integer, “y”: integer, “stage_width”: integer, “stage_height”: integer}"},{"name":"event_count","type":"int","info":"session event counter"},{"name":"event_code","type":"int","info":"event class identifier"}]
# /root/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
train[train.type=='Game'].iloc[364].event_data
# Out:
# '{"description":"Which tub is just right for the chicken?","identifier":"chicken_whichtub","media_type":"animation","duration":3417,"level":10,"round":30,"event_count":365,"game_time":309244,"event_code":3110}'

# %%
# description の有無
# 成功コメントと成功コメント以外の数
