# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/code/data/processed/proceeded_train_20200114_203857.csv', index_col=0)

# %%
test = pd.read_csv('/code/data/processed/proceeded_test_20200114_203857.csv', index_col=0)

# %%
train.head()
# Out:
#    Clip  Activity  Assessment  Game  session_title  count_correct_attempts  \
# 0    11         3           0     4             19                       0
# 1    14         4           1     6             42                       1
# 2    14         4           2     6             19                       1
# 3    24         9           4    10             19                       2
# 4    28        10           5    13             42                       3
#
#    count_uncorrect_attempts  count_accuracy  acc_Chest Sorter (Assessment)  \
# 0                         0             0.0                           -1.0
# 1                         0             1.0                           -1.0
# 2                        11             0.5                           -1.0
# 3                        11             0.5                           -1.0
# 4                        12             0.5                           -1.0
#
# ...

# %%
train.session_title.hist(bins=100)

# %%
event_code=["c51d8688","d51b1749","cf82af56","30614231","f93fc684","1b54d27f","a8a78786","37ee8496","51102b85","2a444e03","01ca3a3c","acf5c23f","86ba578b","a8cc6fec","160654fd","65a38bf7","c952eb01","06372577","d88e8f25","0413e89d","8d7e386c","58a0de5c","4bb2f698","5be391b5","ab4ec3a4","b2dba42b","2b9272f4","7f0836bf","5154fc30","3afb49e6","9ce586dd","16dffff1","2b058fe3","a7640a16","3bfd1a65","bfc77bd6","003cd2ee","fbaf3456","19967db1","df4fe8b6","5290eab1","3bb91dda","6f8106d9","5f0eb72c","5c2f29ca","7d5c30a2","90d848e0","3babcb9b","53c6e11a","d9c005dd","15eb4a7d","15a43e5b","f71c4741","895865f3","b5053438","7da34a02","a5e9da97","a44b10dc","17ca3959","ab3136ba","76babcde","1375ccb7","67439901","363d3849","bcceccc6","90efca10","a6d66e51","90ea0bac","7ab78247","25fa8af4","dcaede90","65abac75","15f99afc","47f43a44","8fee50e2","51311d7a","c6971acf","56bcd38d","c74f40cd","d3268efa","c189aaf2","7ec0c298","9e6b7fb5","5c3d2b2f","e4d32835","0d1da71f","abc5811c","e37a2b78","6d90d394","3d63345e","b012cd7f","792530f8","26a5a3dd","d2e9262e","598f4598","00c73085","7cf1bc53","46b50ba8","ecc36b7f","363c86c9","5859dfb6","8ac7cce4","ecc6157f","daac11b0","4a09ace1","47026d5f","9b4001e4","67aa2ada","f7e47413","cf7638f3","a2df0760","e64e2cfd","119b5b02","1bb5fbdb","1beb320a","7423acbc","14de4c5d","587b5989","828e68f9","3d0b9317","4b5efe37","fcfdffb6","a76029ee","1575e76c","bdf49a58","b2e5b0f1","bd701df8","250513af","6bf9e3e1","7dfe6d8a","9e34ea74","6cf7d25c","1cc7cfca","e79f3763","5b49460a","37c53127","ea296733","b74258a0","02a42007","9b23e8ee","bb3e370b","6f4bd64e","05ad839b","611485c5","a592d54e","c7f7f0e1","857f21c0","6077cc36","3dcdda7f","5e3ea25a","e7561dd2","f6947f54","9e4c8c7b","8d748b58","9de5e594","c54cf6c5","28520915","9b01374f","55115cbd","1f19558b","56cd3b43","795e4a37","83c6c409","3ee399c3","a8876db3","30df3273","77261ab5","4901243f","7040c096","1af8be29","f5b8c21a","499edb7c","6c930e6e","1cf54632","f56e0afc","6c517a88","d38c2fd7","2ec694de","562cec5f","832735e1","736f9581","b1d5101d","36fa3ebe","3dfd4aa4","1c178d24","2dc29e21","4c2ec19f","38074c54","ca11f653","f32856e4","89aace00","29bdd9ba","4ef8cdd3","d2278a3b","0330ab6a","46cd75b4","6f445b57","5e812b27","4e5fc6f5","df4940d3","33505eae","f806dc10","4a4c3d21","cb6010f8","022b4259","99ea62f3","461eace6","ac92046e","0a08139c","fd20ea40","ea321fb1","e3ff61fb","c7128948","31973d56","2c4e6db0","b120f2ac","731c0cbe","d3f1e122","9d4e7b25","cb1178ad","5de79a6a","0d18d96c","a8efe47b","cdd22e43","392e14df","93edfe2e","3ccd3f02","b80e5e84","262136f4","a5be6304","e57dd7af","d3640339","565a3990","beb0a7b9","884228c8","bc8f2793","73757a5e","709b1251","c7fe2a55","3bf1cf26","c58186bf","ad148f58","cfbd47c8","6f4adc4b","e694a35b","222660ff","0086365d","3d8c61b0","37db1c2f","f50fc6c1","8f094001","2a512369","7ad3efc6","e4f1efe6","8af75982","08fd73f3","a1e4395d","3323d7e9","47efca07","5f5b2617","6043a2b4","7d093bf9","907a054b","5e109ec3","cc5087a3","8d84fa81","4074bac2","4d911100","84b0e0c8","45d01abe","0db6d71d","29f54413","1325467d","99abe2bb","f3cd5473","91561152","dcb1663e","f28c589a","0ce40006","7525289a","17113b36","29a42aea","db02c830","ad2fc29c","d185d3ea","37937459","804ee27f","28a4eb9a","49ed92e9","56817e2b","86c924c4","e5c9df6f","b7dc8128","3edf6747","8b757ab8","93b353f2","a52b92d5","9c5ef70c","dcb55a27","d06f75b5","44cb4907","c2baf0bd","27253bdc","a1bbe385","2fb91ec1","155f62a4","ec138c1c","c1cac9a2","eb2c19cd","3ddc79c3","a0faea5d","070a5291","7fd1ac25","69fdac0a","28ed704e","c277e121","13f56524","e720d930","3393b68b","f54238ee","63f13dd7","e9c52111","763fc34e","26fd2d99","7961e599","9d29771f","84538528","77ead60d","3b2048ee","923afab1","3a4be871","9ed8f6da","74e5f8a7","a1192f43","e5734469","d122731b","04df9b66","5348fd84","92687c59","532a2afb","2dcad279","77c76bc5","71e712d8","a16a373e","3afde5dd","d2659ab4","88d4a5be","6088b756","85d1b0de","08ff79ad","15ba1109","7372e1a5","9ee1c98c","71fe8f75","6aeafed4","756e5507","d45ed6a1","1996c610","de26c3a6","1340b8d7","5d042115","e7e44842","2230fab4","9554a50b","4d6737eb","bd612267","3bb91ced","28f975ea","b7530680","b88f38da","5a848010","85de926c","c0415e5c","a29c5338","d88ca108","16667cc5","87d743c1","d02b7a8e","e04fb33d","bbfe0445","ecaab346","48349b14","5dc079d8","e080a381"]

# %%
event_code_list  = ['2050', '4100', '4230', '5000', '4235', '2060', '4110', '5010', '2070', '2075', '2080', '2081', '2083', '3110', '4010', '3120', '3121', '4020', '4021', '4022', '4025', '4030', '4031', '3010', '4035', '4040', '3020', '3021', '4045', '2000', '4050', '2010', '2020', '4070', '2025', '2030', '4080', '2035',
 '2040', '4090', '4220', '4095']

# %%
title_list  = ["All Star Sorting","Welcome to Lost Lagoon!","Scrub-A-Dub","Costume Box","Magma Peak - Level 1","Bubble Bath","Crystal Caves - Level 2","Tree Top City - Level 3","Slop Problem","Happy Camel","Dino Drink","Watering Hole (Activity)","Heavy"," Heavier"," Heaviest","Honey Cake","Crystal Caves - Level 1","Air Show","Chicken Balancer (Activity)","Flower Waterer (Activity)","Cart Balancer (Assessment)","Mushroom Sorter (Assessment)","Leaf Leader","Dino Dive","Pan Balance","Cauldron Filler (Assessment)","Treasure Map","Crystals Rule","Lifting Heavy Things","Rulers","Fireworks (Activity)","Pirate's Tale","12 Monkeys","Balancing Act","Bottle Filler (Activity)","Chest Sorter (Assessment)","Sandcastle Builder (Activity)","Crystal Caves - Level 3","Egg Dropper (Activity)","Magma Peak - Level 2","Tree Top City - Level 2","Ordering Spheres","Chow Time","Bug Measurer (Activity)","Bird Measurer (Assessment)","Tree Top City - Level 1"]

# %%
train['title_list_non_zero'] = train.loc[:, title_list].apply(lambda x: len(x.to_numpy().nonzero()[0]), axis=1)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
train['event_code_non_zero'] = train.loc[:, event_code_list].apply(lambda x: len(x.to_numpy().nonzero()[0]), axis=1)

# %%
train['event_id_non_zero'] = train.loc[:, event_code].apply(lambda x: len(x.to_numpy().nonzero()[0]), axis=1)

# %%
train
# Out:
#        Clip  Activity  Assessment  Game  session_title  \
# 0        11         3           0     4             19
# 1        14         4           1     6             42
# 2        14         4           2     6             19
# 3        24         9           4    10             19
# 4        28        10           5    13             42
# ...     ...       ...         ...   ...            ...
# 17685    26         7           5    11             33
# 17686     3         2           0     3             23
# 17687    11         3           0     4             23
# 17688    23         3           1     6             19
# 17689    24         4           2     6             23
#
#        count_correct_attempts  count_uncorrect_attempts  count_accuracy  \
# 0                           0                         0        0.000000
# 1                           1                         0        1.000000
# 2                           1                        11        0.500000
# ...

# %%
def count_accuracy_label(x):
    if x == 0:
        y = 0
    elif x > 0 and x <= 0.34:
        y = 1
    elif x > 0.34 and x <= 0.67:
        y = 2
    elif x > 0.67 and x < 1:
        y = 3
    elif x == 1:
        y = 4
    return y

# %%
train['count_accuracy_label'] = train.count_accuracy.apply(lambda x: count_accuracy_label(x))

# %%
train['count_accuracy_label']
# Out:
# 0        0
# 1        4
# 2        2
# 3        2
# 4        2
#         ..
# 17685    3
# 17686    0
# 17687    0
# 17688    1
# 17689    1
# Name: count_accuracy_label, Length: 17690, dtype: int64

# %%
train.groupby(['session_title', 'count_accuracy_label'])['accuracy_group'].transform('count')
# Out:
# 0        1115
# 1         463
# 2        1192
# 3        1192
# 4        1012
#          ...
# 17685     621
# 17686    1307
# 17687    1307
# 17688     538
# 17689     614
# Name: accuracy_group, Length: 17690, dtype: int64

# %%
train.head()
# Out:
#    Clip  Activity  Assessment  Game  session_title  count_correct_attempts  \
# 0    11         3           0     4             19                       0
# 1    14         4           1     6             42                       1
# 2    14         4           2     6             19                       1
# 3    24         9           4    10             19                       2
# 4    28        10           5    13             42                       3
#
#    count_uncorrect_attempts  count_accuracy  acc_Chest Sorter (Assessment)  \
# 0                         0             0.0                           -1.0
# 1                         0             1.0                           -1.0
# 2                        11             0.5                           -1.0
# 3                        11             0.5                           -1.0
# 4                        12             0.5                           -1.0
#
# ...

# %%
train[['sum_event_code_2000', 'sum_event_code_3000', 'sum_event_code_4000']].head(20)
# Out:
#     sum_event_code_2000  sum_event_code_3000  sum_event_code_4000
# 0                    79                  188                  380
# 1                   101                  503                  539
# 2                   103                  529                  598
# 3                   196                  807                 1146
# 4                   232                 1086                 1258
# 5                   137                  473                  932
# 6                   159                  555                 1184
# 7                   166                  580                 1276
# 8                     2                    1                    0
# 9                     6                    0                    0
# 10                   12                   18                   40
# 11                   22                   34                   55
# 12                   40                   88                  153
# ...

# %%
 train['sum_event_code_2000']/train[['sum_event_code_2000', 'sum_event_code_3000', 'sum_event_code_4000']].sum(axis=1)
# Out:
# 0        0.122102
# 1        0.088364
# 2        0.083740
# 3        0.091205
# 4        0.090062
#            ...
# 17685    0.104699
# 17686    0.092342
# 17687    0.052575
# 17688    0.064065
# 17689    0.060705
# Length: 17690, dtype: float64

# %%
train['good_comment_ratio'] = train['good_comment'] / train['description']

# %%
importance = pd.read_csv('/code/models/lgb_proceeded_train_20200114_201420_20200114_204742/all_importance.csv', index_col=0)

# %%
importance.mean(axis=1).sort_values(ascending=False).head(20)
# Out:
# session_title                       23659.356177
# mean_accuracy_group                  3954.483435
# count_accuracy                       2385.788042
# Crystal Caves - Level 3              1413.622267
# description_val                      1264.067929
# acc_Bird Measurer (Assessment)       1190.470910
# acc_Chest Sorter (Assessment)         999.623161
# mean_game_round                       948.197975
# Clip                                  854.734135
# 0                                     566.544720
# game_mean_event_count                 532.032170
# 4070                                  507.948232
# 3120                                  507.744856
# 7372e1a5                              488.245725
# good_comment                          485.016217
# acc_Mushroom Sorter (Assessment)      466.157559
# total_duration                        436.816874
# count_uncorrect_attempts              423.876906
# duration_mean                         413.082579
# ...

# %%
train['mean_accuracy_group'].hist()

# %%
def mean_accuracy_group_label_encoder(x):
    if x == 0:
        y = 0
    elif x > 0 and x < 1.0:
        y = 1
    elif x >= 1.0 and x < 2.0:
        y = 2
    elif x >= 2.0 and x < 3.0:
        y = 3
    elif x == 3.0:
        y = 4
    return y

# %%
train['mean_accuracy_group_label'] = train.mean_accuracy_group.apply(lambda x: mean_accuracy_group_label_encoder(x))
test['mean_accuracy_group_label'] = test.mean_accuracy_group.apply(lambda x: mean_accuracy_group_label_encoder(x))

# %%
train['mean_accuracy_group_label'].hist()
test['mean_accuracy_group_label'].hist()

# %%
train['description_val'].hist(bins=30)

# %%
train_ = train.groupby(['session_title', 'description_val'])['accuracy_group'].count()

# %%
test_ = test.groupby(['session_title', 'description_val']).count()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
def list_label_encoder(train, test, columns: list):
    le = LabelEncoder()
    train_description_val_session_title = train[columns].apply(lambda x: str([i for i in x]), axis=1)
    test_description_val_session_title = test[columns].apply(lambda x: str([i for i in x]), axis=1)
    le.fit(train_description_val_session_title)
    le_dict = dict(zip(le.classes_, le.transform(le.classes_)))
    label_name = '_'.join(columns)
    train[f'label_{label_name}'] = train_description_val_session_title.apply(lambda x: le_dict.get(x, -1))
    test[f"label_{label_name}"] = test_description_val_session_title.apply(lambda x: le_dict.get(x, -1))
    return train, test

def frequency_encoder(train, test, columns):
    label_name = '_'.join(columns)
    freq = train[label_name].value_counts()
    train[f'count_{label_name}'] = train[label_name].map(freq)
    test[f'count_{label_name}'] = test[label_name].map(freq)
    return train, test

# %%
def count_accuracy_label_encoder(x):
    if x == 0:
        y = 0
    elif x > 0 and x <= 0.34:
        y = 1
    elif x > 0.34 and x <= 0.67:
        y = 2
    elif x > 0.67 and x < 1:
        y = 3
    elif x == 1:
        y = 4
    return y

# %%
train['count_accuracy_label'] = train.count_accuracy.apply(lambda x: count_accuracy_label_encoder(x))
test['count_accuracy_label'] = test.count_accuracy.apply(lambda x: count_accuracy_label_encoder(x))

# %%
train, test = list_label_encoder(train, test, ['session_title', 'count_accuracy_label'])
train, test = frequency_encoder(train, test, ['session_title', 'count_accuracy_label'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session_title_count_accuracy_label'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-157-1545780bfb8f> in <module>
# ...

# %%
train
# Out:
#        Clip  Activity  Assessment  Game  session_title  \
# 0        11         3           0     4             19
# 1        14         4           1     6             42
# 2        14         4           2     6             19
# 3        24         9           4    10             19
# 4        28        10           5    13             42
# ...     ...       ...         ...   ...            ...
# 17685    26         7           5    11             33
# 17686     3         2           0     3             23
# 17687    11         3           0     4             23
# 17688    23         3           1     6             19
# 17689    24         4           2     6             23
#
#        count_correct_attempts  count_uncorrect_attempts  count_accuracy  \
# 0                           0                         0        0.000000
# 1                           1                         0        1.000000
# 2                           1                        11        0.500000
# ...

# %%
train
# Out:
#        Clip  Activity  Assessment  Game  session_title  \
# 0        11         3           0     4             19
# 1        14         4           1     6             42
# 2        14         4           2     6             19
# 3        24         9           4    10             19
# 4        28        10           5    13             42
# ...     ...       ...         ...   ...            ...
# 17685    26         7           5    11             33
# 17686     3         2           0     3             23
# 17687    11         3           0     4             23
# 17688    23         3           1     6             19
# 17689    24         4           2     6             23
#
#        count_correct_attempts  count_uncorrect_attempts  count_accuracy  \
# 0                           0                         0        0.000000
# 1                           1                         0        1.000000
# 2                           1                        11        0.500000
# ...

# %%
A = ['a', 'b', 'c']
'_'.join(A)
# Out:
# 'a_b_c'

# %%
train['count_description_val_session_title'].hist()
test['count_description_val_session_title'].hist()

# %%
train[['session_title', 'description_val']].apply(lambda x: tuple([i for i in x]), axis=1)
# Out:
# 0         (19, 9)
# 1        (42, 14)
# 2         (19, 5)
# 3         (19, 6)
# 4        (42, 14)
#            ...
# 17685     (33, 6)
# 17686    (23, 19)
# 17687     (23, 9)
# 17688     (19, 9)
# 17689    (23, 10)
# Length: 17690, dtype: object

# %%
p01 = train['frequency'].quantile(0.01)
p99 = train['frequency'].quantile(0.99)
train['frequency'] = train['frequency'].clip(p01, p99)
test['frequency'] = test['frequency'].clip(p01, p99)

# %%
np.log1p(train['frequency']).hist(bins=25)
np.log1p(test['frequency']).hist(bins=25)

# %%
def frequency_label_encoder(x):
    if x <= 0.1:
        y = 0
    elif x > 0.1 and x <= 0.2:
        y = 1
    elif x > 0.2 and x <= 0.3:
        y = 2
    elif x > 0.3 and x <= 0.4:
        y = 3
    elif x > 0.4 and x <= 0.5:
        y = 4
    elif x > 0.5 and x <= 1.0:
        y=5
    else:
        y=6
    return y

# %%
train['label_frequency'] = train.frequency.apply(lambda x: frequency_label_encoder(np.log1p(x)))
test['label_frequency'] = test.frequency.apply(lambda x: frequency_label_encoder(np.log1p(x)))

# %%
test['label_frequency'].hist()

# %%
test_.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
np.log1p(train['count_actions']).hist(bins=10)
np.log1p(test['count_actions']).hist(bins=10)

# %%
def bins_count_action_label_encoder(x):
    if x < 1.0:
        y = 0
    elif x >= 1.0 and x < 2.0:
        y = 1
    elif x >= 2.0 and x < 3.0:
        y = 2
    elif x >= 3.0 and x < 4.0:
        y = 3
    elif x >= 4.0 and x < 5.0:
        y = 4
    elif x >= 5.0 and x < 6.0:
        y = 5
    elif x >= 6.0 and x < 7.0:
        y = 6
    elif x >= 7.0 and x < 8.0:
        y = 7
    elif x >= 8.0 and x < 9.0:
        y = 8
    else:
        y = 9
    return y

# %%
test['bins_count_action'] = test.count_actions.apply(lambda x: bins_count_action_label_encoder(np.log1p(x)))

# %%
train['bins_count_action'] = train.count_actions.apply(lambda x: bins_count_action_label_encoder(np.log1p(x)))

# %%
train['bins_count_action'].hist()
test['bins_count_action'].hist()

# %%
train.columns
# Out:
# Index(['Clip', 'Activity', 'Assessment', 'Game', 'session_title',
#        'count_correct_attempts', 'count_uncorrect_attempts', 'count_accuracy',
#        'acc_Chest Sorter (Assessment)', 'acc_Cart Balancer (Assessment)',
#        ...
#        'sum_event_code_3000', 'sum_event_code_4000', 'title_list_non_zero',
#        'event_code_non_zero', 'event_id_non_zero', 'count_accuracy_label',
#        'good_comment_ratio', 'mean_accuracy_group_label',
#        'count_description_val_session_title',
#        'count_count_accuracy_label_session_title'],
#       dtype='object', length=959)

# %%
train.groupby('session_title').unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-df90f4923161> in <module>
# ----> 1 train.groupby('session_title').unique()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     564
#     565         raise AttributeError(
# --> 566             "%r object has no attribute %r" % (type(self).__name__, attr)
#     567         )
#     568
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'unique'
