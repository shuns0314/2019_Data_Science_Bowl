# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
score = {
    'cluster': [20, 10, 5, 15, 8, 40, 100, 12, 11, 9],
    'score': [0.5405702500314389, 0.547195841544831, 0.539194685426726, 0.5428718340202685, 0.5292757512001915, 0.5380896247219886, 0.5390959134883593, 0.531377371139613, 0.5458867593035394, 0.5351377882405554]
 }

# %%
score_df = pd.DataFrame.from_dict(score)

# %%
plt.scatter(x=score_df['cluster'], y=score_df['score'])
plt.ylim(0.52, 0.55)
plt.xlim(0,20)
plt.grid()
