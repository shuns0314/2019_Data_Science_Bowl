# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
RAW_PATH = "/Users/shunak/Desktop/data_science_bawl/2019_Data_Science_Bawl/data/raw"

# %%
train_df = pd.read_csv(f"{RAW_PATH}/train.csv")
train_labels_df = pd.read_csv(f"{RAW_PATH}/train_labels.csv")
specs_df = pd.read_csv(f"{RAW_PATH}/specs.csv")
test_df = pd.read_csv(f"{RAW_PATH}/test.csv")
sample_df = pd.read_csv(f"{RAW_PATH}/sample_submission.csv")

# %% [markdown]
# ### train_df

# %%
train_df.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1  27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2  77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3  b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4  1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        0001e90f
# 1             {"event_code": 2000, "event_count": 1}        0001e90f
# 2  {"version":"1.0","event_count":1,"game_time":0...        0001e90f
# 3  {"description":"Let's build a sandcastle! Firs...        0001e90f
# 4  {"description":"Let's build a sandcastle! Firs...        0001e90f
#
#    event_count  event_code  game_time                          title  \
# 0            1        2000          0        Welcome to Lost Lagoon!
# 1            1        2000          0           Magma Peak - Level 1
# ...

# %%
train_df.describe()
# Out:
#         event_count    event_code     game_time
# count  1.134104e+07  1.134104e+07  1.134104e+07
# mean   1.056642e+02  3.513838e+03  1.976236e+05
# std    1.483477e+02  6.816470e+02  1.803968e+06
# min    1.000000e+00  2.000000e+03  0.000000e+00
# 25%    2.500000e+01  3.021000e+03  3.061800e+04
# 50%    6.100000e+01  4.020000e+03  7.276100e+04
# 75%    1.290000e+02  4.035000e+03  1.574460e+05
# max    3.368000e+03  5.010000e+03  3.069102e+08

# %%
train_df[train_df.installation_id=="0006a69f"][train_df.event_code==2000][train_df.type=="Assessment"]
# Out:
# C:\Users\shunak\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\shunak\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#       event_id      game_session                 timestamp  \
# 2185  3bfd1a65  901acc108f55a5a1  2019-08-06T05:22:01.344Z
# 2681  f56e0afc  77b8ee947eb84b4e  2019-08-06T05:35:19.167Z
# 2768  3bfd1a65  6bdf9623adc94d89  2019-08-06T05:37:50.020Z
# 3680  3bfd1a65  e7e7db2a241eadcc  2019-08-06T20:34:35.357Z
# 3697  3bfd1a65  9501794defd84e4d  2019-08-06T20:34:53.812Z
# 4124  f56e0afc  a9ef3ecb3d1acc6a  2019-08-06T20:49:59.095Z
#
#                                              event_data installation_id  \
# 2185  {"version":"1.0","event_count":1,"game_time":0...        0006a69f
# ...

# %% [markdown]
# ### train_labels

# %%
train_labels_df.head()
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %%
train_labels_df.describe()
# Out:
#         num_correct  num_incorrect      accuracy  accuracy_group
# count  17690.000000   17690.000000  17690.000000    17690.000000
# mean       0.760938       1.587790      0.595810        1.885585
# std        0.426523       3.058295      0.430559        1.256796
# min        0.000000       0.000000      0.000000        0.000000
# 25%        1.000000       0.000000      0.111111        1.000000
# 50%        1.000000       0.500000      0.750000        2.500000
# 75%        1.000000       2.000000      1.000000        3.000000
# max        1.000000      85.000000      1.000000        3.000000

# %%
train_labels_df[train_labels_df.installation_id=="0006a69f"]
# Out:
#        game_session installation_id                         title  \
# 0  6bdf9623adc94d89        0006a69f  Mushroom Sorter (Assessment)
# 1  77b8ee947eb84b4e        0006a69f    Bird Measurer (Assessment)
# 2  901acc108f55a5a1        0006a69f  Mushroom Sorter (Assessment)
# 3  9501794defd84e4d        0006a69f  Mushroom Sorter (Assessment)
# 4  a9ef3ecb3d1acc6a        0006a69f    Bird Measurer (Assessment)
#
#    num_correct  num_incorrect  accuracy  accuracy_group
# 0            1              0       1.0               3
# 1            0             11       0.0               0
# 2            1              0       1.0               3
# 3            1              1       0.5               2
# 4            1              0       1.0               3

# %% [markdown]
# ### specs

# %%
specs_df.head()
# Out:
#    event_id                                               info  \
# 0  2b9272f4  The end of system-initiated feedback (Correct)...
# 1  df4fe8b6  The end of system-initiated feedback (Incorrec...
# 2  3babcb9b  The end of system-initiated instruction event ...
# 3  7f0836bf  The end of system-initiated instruction event ...
# 4  ab3136ba  The end of system-initiated instruction event ...
#
#                                                 args
# 0  [{"name":"game_time","type":"int","info":"mill...
# 1  [{"name":"game_time","type":"int","info":"mill...
# 2  [{"name":"game_time","type":"int","info":"mill...
# 3  [{"name":"game_time","type":"int","info":"mill...
# 4  [{"name":"game_time","type":"int","info":"mill...

# %%
specs_df.describe()
# Out:
#         event_id                                               info  \
# count        386                                                386
# unique       386                                                168
# top     44cb4907  This event occurs when the player clicks on th...
# freq           1                                                 17
#
#                                                      args
# count                                                 386
# unique                                                191
# top     [{"name":"game_time","type":"int","info":"mill...
# freq                                                   25

# %% [markdown]
# ### test_df

# %%
test_df.head()
# Out:
#    event_id      game_session                 timestamp  \
# 0  27253bdc  0ea9ecc81a565215  2019-09-10T16:50:24.910Z
# 1  27253bdc  c1ea43d8b8261d27  2019-09-10T16:50:55.503Z
# 2  27253bdc  7ed86c6b72e725e2  2019-09-10T16:51:51.805Z
# 3  27253bdc  7e516ace50e7fe67  2019-09-10T16:53:12.825Z
# 4  7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
#
#                                           event_data installation_id  \
# 0             {"event_code": 2000, "event_count": 1}        00abaee7
# 1             {"event_code": 2000, "event_count": 1}        00abaee7
# 2             {"event_code": 2000, "event_count": 1}        00abaee7
# 3             {"event_code": 2000, "event_count": 1}        00abaee7
# 4  {"version":"1.0","round":0,"event_count":1,"ga...        00abaee7
#
#    event_count  event_code  game_time                    title  type  \
# 0            1        2000          0  Welcome to Lost Lagoon!  Clip
# 1            1        2000          0     Magma Peak - Level 1  Clip
# ...

# %%
test_df[test_df.installation_id=="00abaee7"][test_df.event_code==2000][test_df.type=="Assessment"]
# Out:
# C:\Users\shunak\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\shunak\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      event_id      game_session                 timestamp  \
# 282  7ad3efc6  8b38fc0d2fd315dc  2019-09-11T18:56:11.918Z
# 867  90d848e0  348d7f09f96af313  2019-09-12T13:52:12.193Z
#
#                                             event_data installation_id  \
# 282  {"version":"1.0","event_count":1,"game_time":0...        00abaee7
# 867  {"version":"1.0","event_count":1,"game_time":0...        00abaee7
#
#      event_count  event_code  game_time                         title  \
# 282            1        2000          0    Cart Balancer (Assessment)
# ...

# %%
test_df[test_df.installation_id=="00abaee7"][test_df.title=="Chow Time"]
# Out:
# C:\Users\shunak\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      event_id      game_session                 timestamp  \
# 4    7d093bf9  a022c3f60ba547e7  2019-09-10T16:54:12.115Z
# 5    f93fc684  a022c3f60ba547e7  2019-09-10T16:54:14.338Z
# 6    7ec0c298  a022c3f60ba547e7  2019-09-10T16:54:16.553Z
# 7    0d1da71f  a022c3f60ba547e7  2019-09-10T16:54:23.364Z
# 8    63f13dd7  a022c3f60ba547e7  2019-09-10T16:54:23.365Z
# 9    7372e1a5  a022c3f60ba547e7  2019-09-10T16:54:25.029Z
# 10   cfbd47c8  a022c3f60ba547e7  2019-09-10T16:54:26.776Z
# 11   d185d3ea  a022c3f60ba547e7  2019-09-10T16:54:26.891Z
# 12   cfbd47c8  a022c3f60ba547e7  2019-09-10T16:54:28.460Z
# 13   d185d3ea  a022c3f60ba547e7  2019-09-10T16:54:28.608Z
# 14   cfbd47c8  a022c3f60ba547e7  2019-09-10T16:54:29.479Z
# 15   d185d3ea  a022c3f60ba547e7  2019-09-10T16:54:29.592Z
# ...

# %%
# 予測対象
test_df.groupby("installation_id").last()
# Out:
#                  event_id      game_session                 timestamp  \
# installation_id
# 00abaee7         90d848e0  348d7f09f96af313  2019-09-12T13:52:12.193Z
# 01242218         7ad3efc6  1fef5d54cb4b775a  2019-10-09T20:23:16.209Z
# 017c5718         3bfd1a65  4b165a330a0bdd6c  2019-09-21T11:28:21.757Z
# 01a44906         3bfd1a65  be0b655ad1fee30c  2019-07-27T16:28:10.394Z
# 01bc6cb6         7ad3efc6  46e8bbed71df7520  2019-09-06T18:05:26.197Z
# 02256298         7ad3efc6  73cf848935e13a2e  2019-08-25T19:16:14.447Z
# 0267757a         3bfd1a65  363c252fbb51ba5a  2019-10-01T18:02:11.838Z
# 027e7ce5         f56e0afc  3f92464665bbc7e8  2019-09-23T19:21:45.255Z
# 02a29f99         5b49460a  3d5b5a3897771980  2019-08-17T18:53:01.548Z
# 0300c576         7ad3efc6  b1e50bb61bf9a4d4  2019-09-01T22:06:38.480Z
# 03885368         3bfd1a65  2ecd4d1dd5167550  2019-10-02T23:02:55.724Z
# 03ac279b         3bfd1a65  16a45e446ce6dfbc  2019-07-26T13:14:42.516Z
# ...

# %%
train_df.groupby("installation_id").last()
# Out:
#                  event_id      game_session                 timestamp  \
# installation_id
# 0001e90f         27253bdc  04168b61c0650977  2019-09-06T18:18:42.392Z
# 000447c4         4d911100  356348f67a1dfb26  2019-10-11T15:03:37.812Z
# 0006a69f         76babcde  0721802df0531701  2019-08-29T16:39:12.615Z
# 0006c192         27253bdc  df16e87c1003851d  2019-10-01T01:04:36.492Z
# 0009a5a9         d3640339  d78d2fa8766987f0  2019-09-11T19:17:40.502Z
# 0011edc8         27253bdc  aac21ce0f1c9ba71  2019-09-04T14:25:43.395Z
# 00129856         84b0e0c8  9587e9286126197c  2019-09-22T16:55:24.823Z
# 0016b7cc         8af75982  fb13c8a7665bd25c  2019-09-04T15:33:33.542Z
# 00195df7         27253bdc  6116bec8c57327d3  2019-10-10T19:05:43.855Z
# 001d0ed0         27253bdc  80dc2daa4636a50f  2019-09-13T19:24:39.970Z
# 002114ae         63f13dd7  dd28fcf50eb85acf  2019-09-04T17:12:14.838Z
# 00219589         27253bdc  f4e9e94fe4b4c0b0  2019-08-02T00:22:37.816Z
# ...

# %%
train_df.groupby("installation_id")

# %%
for i, (a, b) in enumerate(train_df.groupby("installation_id")):
    print(a,b)
    if i==10:
        break
# Out:
# 0001e90f       event_id      game_session                 timestamp  \
# 0     27253bdc  45bb1e1b6b50c07b  2019-09-06T17:53:46.937Z
# 1     27253bdc  17eeb7f223665f53  2019-09-06T17:54:17.519Z
# 2     77261ab5  0848ef14a8dc6892  2019-09-06T17:54:56.302Z
# 3     b2dba42b  0848ef14a8dc6892  2019-09-06T17:54:56.387Z
# 4     1bb5fbdb  0848ef14a8dc6892  2019-09-06T17:55:03.253Z
# 5     1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.279Z
# 6     1325467d  0848ef14a8dc6892  2019-09-06T17:55:06.913Z
# 7     1325467d  0848ef14a8dc6892  2019-09-06T17:55:07.546Z
# 8     1325467d  0848ef14a8dc6892  2019-09-06T17:55:07.979Z
# 9     1325467d  0848ef14a8dc6892  2019-09-06T17:55:08.566Z
# 10    1325467d  0848ef14a8dc6892  2019-09-06T17:55:08.966Z
# 11    1325467d  0848ef14a8dc6892  2019-09-06T17:55:09.673Z
# 12    1325467d  0848ef14a8dc6892  2019-09-06T17:55:09.930Z
# 13    1325467d  0848ef14a8dc6892  2019-09-06T17:55:10.157Z
# 14    1325467d  0848ef14a8dc6892  2019-09-06T17:55:10.414Z
# ...

# %%
len(train_labels_df)
# Out:
# 17690

# %% [markdown]
# ### sample_submission

# %%
sample_df[sample_df.installation_id== "00abaee7"]
# Out:
#   installation_id  accuracy_group
# 0        00abaee7               3
